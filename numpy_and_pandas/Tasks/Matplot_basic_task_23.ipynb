# %% [markdown]
# <a href="https://colab.research.google.com/github/sinara08/Practice_Python/blob/main/numpy_and_pandas/Tasks/Matplot_basic_task_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

plt.style.use('default')

# %% [markdown]
# ## `Problem 1 to 5`:
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.
#
# ### **`Problem-1:`** Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
# code here
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://tinyurl.com/2fe6vz4u')
df=df.drop('Unnamed: 0', axis=1)

# %%
#df = df[(df['Country']=='Iran') | (df['Country']=='China')]

df = df[(df['Country']=='Iran') | (df['Country']=='China')].groupby('Year')['PM2.5'].sum().reset_index()

# %%
df
# Out:
#    Year  PM2.5
# 0  2012     37
# 1  2013     66
# 2  2014   2756
# 3  2015    425
# 4  2016  12559

# %%
import matplotlib.ticker
plt.plot(df['Year'], df['PM2.5'])
plt.title('Year Vs PM2.5')
plt.xlabel('Year')
plt.ylabel('PM2.5')
formatter = matplotlib.ticker.StrMethodFormatter("{x:.0f}")
plt.gca().xaxis.set_major_formatter(formatter)
plt.show()

# %% [markdown]
# ### **`Problem-2:`** Draw a histogram of the  column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
# code here

# %% [markdown]
# ### **`Problem-3:`** Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
# code here
df1 = df[(df['Country']=='Poland') | (df['Country']=='Chile')][['PM2.5', 'PM10']]

# %%
df1
# Out:
#      PM2.5  PM10
# 75      67    85
# 89      64    75
# 190     49    64
# 254     44    56
# 280     41    67
# 338     35    67
# 339     35    52
# 357     33    62
# 358     33    57
# 370     33    43
# 371     33    38
# 372     32    65
# 373     32    69
# 392     32    46
# 394     31    66
# 404     31    42
# 405     31    41
# 409     30    89
# 425     30    41
# 431     29    62
# 432     29    65
# 433     29    67
# 446     29    35
# 447     29    38
# 448     29    42
# 449     28    47
# 450     28    68
# 471     28    36
# 472     28    38
# 475     27    55
# 492     27    35
# 493     27    33
# 494     27    32
# 495     27    31
# 496     27    29
# 497     27    35

# %%
plt.scatter(df['PM2.5'], df['PM10'])
plt.title('PM2.5 Vs PM10 of Poland and Chile')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.show()

# %% [markdown]
# ### **`Problem-4:`** Draw a pie chart of top 5 most frequent countries.

# %%
# code here
df2 = df['Country'].value_counts().head(5).reset_index()
df2.columns = ['Country', 'Count']
df2
# Out:
#   Country  Count
# 0   China    283
# 1    Iran     43
# 2   India     32
# 3   Chile     19
# 4  Poland     17

# %%
plt.pie(df2['Count'],labels=df2['Country'],autopct='%0.1f%%')
        #,labels=df2['Country'],autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### **`Problem-5:`** Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
# code here
plt.bar(df2['Country'], df2['Count'], color = 'Blue')
plt.title('Counts of top 5 most frequent countries')
plt.xlabel('Country')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##`Problem 6-10`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.
#
#
# ###`Problem-6`
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
# code here
df=pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv')

df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['month_number'], df['total_profit'], linestyle='dotted', color='blue', marker='o', label='Total_Profit')

plt.title('Total Profit for each month')
plt.xlabel('Month')
plt.ylabel('Total_Profit')

plt.legend()

# %% [markdown]
# ###`Problem-7`
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
# code here

ds = df[df['month_number'] == 3][['facecream',	'facewash','toothpaste','bathingsoap',	'shampoo',	'moisturizer']].unstack().reset_index()
ds.drop('level_1', axis = 1, inplace=True)

# %%
ds.columns = ['Product', 'Sale']
ds
# Out:
#        Product  Sale
# 0    facecream  2140
# 1     facewash  1340
# 2   toothpaste  4550
# 3  bathingsoap  9550
# 4      shampoo  3550
# 5  moisturizer  1340

# %%
plt.pie(ds['Sale'], labels = ds['Product'], autopct='%0.1f%%', explode=[0,0,0.3,0,0,0],shadow=True)
plt.title('                                     Sales in March')
plt.show()

# %% [markdown]
# ###`Problem-8` Multiline Plot of all products sales.
# * Give different styes for each products
# * Add legend at top right

# %%
ds1 = df[['month_number','facecream',	'facewash','toothpaste','bathingsoap',	'shampoo',	'moisturizer']]
#.unstack().reset_index()
#ds1.drop('level_1', axis = 1, inplace=True)
ds1
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer
# 0          1500
# 1          1200
# 2          1340
# 3          1130
# 4          1740
# 5          1555
# 6          1120
# 7          1400
# 8          1780
# 9          1890
# 10         2100
# 11         1760

# %%
# code here

# show
plt.plot(ds1['month_number'],ds1['facecream'],color='#D9F10F',linestyle='solid',linewidth=3,marker='D',markersize=10, label='facecream')
plt.plot(ds1['month_number'],ds1['facewash'],color='#FC00D6',linestyle='solid',linewidth=2,marker='o', label='facewash')
plt.plot(ds1['month_number'],ds1['toothpaste'],color='#003399',linestyle='dashdot',linewidth=2,marker='o', label='toothpaste')
plt.plot(ds1['month_number'],ds1['bathingsoap'],color='#660033',linestyle='dashdot',linewidth=2,marker='o', label='bathingsoap')
plt.plot(ds1['month_number'],ds1['shampoo'],color='#ffff00',linestyle='dashdot',linewidth=2,marker='o', label='shampoo')
plt.plot(ds1['month_number'],ds1['moisturizer'],color='#00ff00',linestyle='dashdot',linewidth=2,marker='o', label='moisturizer')

plt.title('All products sales')
plt.xlabel('Month')
plt.ylabel('Product')

plt.grid()
plt.legend(loc='upper right')

plt.show()

# %% [markdown]
# ###`Problem-9` Show Quarter wise Sales data for all products as multi Bar chart.

# %%
# code here

# %% [markdown]
# ###`Problem-10` Plot Stacked Bar chart quarter wise for each product.

# %%
# code here
